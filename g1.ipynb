# %%
import pandas as pd 

df = pd.read_csv('DKSalaries1.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-54dab3c4e8a9> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('DKSalaries1.csv')
#       4 df
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
import pandas as pd 
df = pd.read_csv('DKSalaries1.csv')
df = df[df['AvgPointsPerGame']> 11]
df['ptsVal'] = df['AvgPointsPerGame']/(df['Salary']/1000)
df[df['Roster Position'] == 'CPT'].sort_values(by=['ptsVal'],ascending=False)
# Out:
#    Position                         Name + ID                   Name  \
# 39       RB      Leonard Fournette (15817569)      Leonard Fournette
# 31       RB  Darrell Henderson Jr. (15817566)  Darrell Henderson Jr.
# 8        QB              Tom Brady (15817553)              Tom Brady
# 10       QB             Jared Goff (15817554)             Jared Goff
# 20       WR           Robert Woods (15817559)           Robert Woods
# 19       WR           Chris Godwin (15817558)           Chris Godwin
# 17       RB        Ronald Jones II (15817557)        Ronald Jones II
# 13       WR             Mike Evans (15817556)             Mike Evans
# 12       WR            Cooper Kupp (15817555)            Cooper Kupp
#
#           ID Roster Position  Salary                     Game Info TeamAbbrev  \
# 39  15817569            FLEX    4400  LAR@TB 11/23/2020 08:15PM ET         TB
# 31  15817566            FLEX    5800  LAR@TB 11/23/2020 08:15PM ET        LAR
# ...

# %%
import pandas as pd 
Budget = 50000 - 2100

df = pd.read_csv('DKSalaries.csv').sort_values(by=['AvgPointsPerGame'],ascending=False)
df['RankedPts'] = df['AvgPointsPerGame']/(df['Salary']/1000)

df = df[df['Salary']>1000]

df = df.sort_values(by=['AvgPointsPerGame'],ascending=False)
df
# Out:
#    Position                         Name + ID                   Name  \
# 55       RB        Ke'Shawn Vaughn (15817627)        Ke'Shawn Vaughn
# 52       WR          Scotty Miller (15817625)          Scotty Miller
# 53       WR          Tyler Johnson (15817626)          Tyler Johnson
# 42       TE         Gerald Everett (15817623)         Gerald Everett
# 38      DST                  Rams  (15817621)                  Rams
# 25       RB      Leonard Fournette (15817615)      Leonard Fournette
# 30        K            Ryan Succop (15817616)            Ryan Succop
# 32      DST            Buccaneers  (15817617)            Buccaneers
# 47       TE          Cameron Brate (15817624)          Cameron Brate
# 18       RB  Darrell Henderson Jr. (15817612)  Darrell Henderson Jr.
# 0        QB              Tom Brady (15817599)              Tom Brady
# 1        QB             Jared Goff (15817600)             Jared Goff
# 23       TE           Tyler Higbee (15817614)           Tyler Higbee
# ...

# %%
df = df.sort_values(by=['AvgPointsPerGame'],ascending=False)
df
# Out:
#    Position                         Name + ID                   Name  \
# 8        QB              Tom Brady (15817553)              Tom Brady
# 0        QB              Tom Brady (15817599)              Tom Brady
# 10       QB             Jared Goff (15817554)             Jared Goff
# 1        QB             Jared Goff (15817600)             Jared Goff
# 20       WR           Robert Woods (15817559)           Robert Woods
# 6        WR           Robert Woods (15817605)           Robert Woods
# 4        RB        Ronald Jones II (15817603)        Ronald Jones II
# 17       RB        Ronald Jones II (15817557)        Ronald Jones II
# 2        WR            Cooper Kupp (15817601)            Cooper Kupp
# 12       WR            Cooper Kupp (15817555)            Cooper Kupp
# 13       WR             Mike Evans (15817556)             Mike Evans
# 3        WR             Mike Evans (15817602)             Mike Evans
# 5        WR           Chris Godwin (15817604)           Chris Godwin
# ...

# %%
players = [1,0,0,0,0,0]
df = df.sort_values(by=['AvgPointsPerGame'],ascending=False)
for
